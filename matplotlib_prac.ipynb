# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek-varshney/Practice/blob/main/matplotlib_prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.diag([4,56,6,7,7,8])
# Out:
# array([[ 4,  0,  0,  0,  0,  0],
#        [ 0, 56,  0,  0,  0,  0],
#        [ 0,  0,  6,  0,  0,  0],
#        [ 0,  0,  0,  7,  0,  0],
#        [ 0,  0,  0,  0,  7,  0],
#        [ 0,  0,  0,  0,  0,  8]])

# %%
np.random.random(2)
# Out:
# array([0.72041648, 0.08916703])

# %%
np.random.random((4,5))
# Out:
# array([[0.19762109, 0.56557264, 0.25953586, 0.74472366, 0.03323435],
#        [0.56271443, 0.82733004, 0.45285135, 0.92290809, 0.95330522],
#        [0.61661932, 0.75858032, 0.4677442 , 0.38504831, 0.77011521],
#        [0.37009079, 0.78788443, 0.76435941, 0.4555086 , 0.98175559]])

# %%
N = np.random.randn(1000,4)

# %%
N.mean(axis = 0)
# Out:
# array([-0.02088587,  0.03881486, -0.05638935, -0.00693075])

# %%
x = np.linspace(0,50,1000)
x.shape
# Out:
# (1000,)

# %%
y = np.sin(x) + (x*0.1)
y.shape
# Out:
# (1000,)

# %%
plt.plot(x,y)
plt.xlabel("range")
plt.ylabel("variation")
plt.title("ploting");

# %% [markdown]
# Scatter plot

# %%
plt.scatter(x,y);

# %%
X = np.random.randn(50,2)
plt.scatter(X[:,0],X[:,1]);

# %%
X = np.random.randn(500,2)
plt.scatter(X[:,0],X[:,1],c='b');

# %%
X = np.random.randn(500,2)
X[:200]+=2
Y = np.zeros(500)
Y[:200] = 2
plt.scatter(X[:,0],X[:,1],c=Y);

# %%
X1= np.random.randn(5000)
plt.hist(X1,bins=50);
